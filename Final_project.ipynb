# %% [markdown]
# # Final project - Open Science Practices In Remote Sensing

# %% [markdown]
# # Introduction to Sourcetree and Pickle

# %% [markdown]
# # [Sourcetree](https://www.sourcetreeapp.com/)

# %% [markdown]
# Sourcetree is a free Git and Mercurial desktop client, developed by Atlassian, which provides a graphical user interface (GUI) for managing and interacting with version control repositories.
#
# With Sourcetree, users can easily clone, create, and manage Git and Mercurial repositories. It simplifies many complex version control tasks by providing an intuitive and user-friendly interface. Some of its key features include:
#
# 1. Repository Management: Sourcetree allows users to clone, create, and manage repositories from various hosting services like GitHub, Bitbucket, and GitLab. It provides an easy way to browse repositories, view branches, and access commit history.
#
# 2. Visual Branching and Merging: Sourcetree offers a visual representation of branches, making it easier to understand and manage complex branching structures. Users can visually compare branches, merge changes, and resolve conflicts within the GUI.

# %% [markdown]
# To download sourtree, click on the "Sourcetree" title. After that, link your git account (from gitlab, github, bitbucket, or others) to the software and once it is done, you will be ready to start!
#
# For this project purposes, I have created a project on github called "Final_project_open_science" which we will clone from the remote repository to our local machine through Sourcetree.
#
# First step - clone the repo: For this, we will use the HTTPS link provided by github/gitlab/bitbucket and paste it in a new tab on sourcetree. Moreover, we have to choose a folder destination where our local repository will be stored.

# %% [markdown]
# ## Clone repo

# %% [markdown]
# ![step1_clone_repo.png](attachment:step1_clone_repo.png)

# %% [markdown]
# First look from folder and Sourcetree: This is our local repository where I have started a jupyter notebook file called "Final_project.ipynb"

# %% [markdown]
# ![folder.png](attachment:folder.png)

# %% [markdown]
# ![sourcetree_first_look.png](attachment:sourcetree_first_look.png)

# %% [markdown]
# ## Creating new branches

# %% [markdown]
# Creating new branches: Because I am used to work in a different branch besides "Main", I created a new branch called "Develop".

# %% [markdown]
# ![sourcetree_creating_branch.png](attachment:sourcetree_creating_branch.png)

# %% [markdown]
# First commit from our new branch: Once we are ready to commit something, the "File Status" tab will report it and we can stage all the files, click on "Push changes immediately to -" to push the commit from the local repository to the remote repository, and finally, write something that respresents the changes and commit it!

# %% [markdown]
# ![sourcetree_commit.png](attachment:sourcetree_commit.png)

# %% [markdown]
# How does it look? So, now we can see our commit in our local/remote repository.

# %% [markdown]
# ![sourcetree_after_commit.png](attachment:sourcetree_after_commit.png)

# %% [markdown]
# ## Merge branches

# %% [markdown]
# All the attached screenshots and explanations were commit in a new branch called "Sourcetree" as you can see below.

# %% [markdown]
# ![before_merge.png](attachment:before_merge.png)

# %% [markdown]
# I commit a last update in Sourcetree saying "feat: before merge branch from sourcetree to develop" in the Sourcetree branch.

# %% [markdown]
# Double click in the develop branch, to come back to develop.

# %% [markdown]
# ![step1_merge.png](attachment:step1_merge.png)

# %% [markdown]
# Right click on the Sourcetree branch and select "Merge Sourcetree into current branch" to merge Sourcetree into develop.

# %% [markdown]
# ![step2_merge.png](attachment:step2_merge.png)

# %% [markdown]
# Sourcetree will notify that there are some changes to push from the local repository to the remote repository.

# %% [markdown]
# ![step3_merge.png](attachment:step3_merge.png)

# %% [markdown]
# Push the involved branches.

# %% [markdown]
# ![step4_merge.png](attachment:step4_merge.png)

# %% [markdown]
# You can delete the previous branch. This is OPTIONAL.

# %% [markdown]
# ![optional_merge.png](attachment:optional_merge.png)

# %% [markdown]
# This is how it looks now! Sourcetree is not there anymore and all the changes we made are into develop now.

# %% [markdown]
# ![second_look.png](attachment:second_look.png)

# %% [markdown]
# # Pickle
