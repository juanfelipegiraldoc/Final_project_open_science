# %% [markdown]
# # Final project - Open Science Practices In Remote Sensing

# %% [markdown]
# ## Introduction to Sourcetree and Pickle

# %% [markdown]
# ## [Sourcetree](https://www.sourcetreeapp.com/)

# %% [markdown]
# ![step1_clone_repo.png](attachment:step1_clone_repo.png)

# %% [markdown]
# ![sourcetree_first_look.png](attachment:sourcetree_first_look.png)

# %% [markdown]
# ![sourcetree_creating_branch.png](attachment:sourcetree_creating_branch.png)
